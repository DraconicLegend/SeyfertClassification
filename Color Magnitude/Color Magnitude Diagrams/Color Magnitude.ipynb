# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("Color Magnitude.csv")
df = df.dropna(subset=['B'])
df = df.dropna(subset=['V'])

# %%
new_Sy1=df[df['otype']=="Sy1"]
new_Sy2=df[df['otype']=="Sy2"]
s1b = new_Sy1.B.to_numpy()
s1v = new_Sy1.V.to_numpy()
s2b = new_Sy2.B.to_numpy()
s2v = new_Sy2.V.to_numpy()

# %%
plt.scatter(s1b-s1v,s1b)
plt.scatter(s2b-s2v,s2b)

# %%
plt.scatter(s1b-s1v,s1v)
plt.scatter(s2b-s2v,s2v)

# %%
plt.scatter(s1v-s1b,s1v)
plt.scatter(s2v-s2b,s2v)

# %%
plt.scatter(s1v-s1b,s1b)
plt.scatter(s2v-s2b,s2b)
